# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress
import seaborn as sns
from scipy import stats
from matplotlib.pyplot import figure
import scipy.stats as st

# %%
covid_file = './Resources/owid-covid-data.csv'

# %%
covid_file = pd.read_csv(covid_file)

# %%
covid_file.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  24/02/2020          5.0        5.0
# 1      AFG      Asia  Afghanistan  25/02/2020          5.0        0.0
# 2      AFG      Asia  Afghanistan  26/02/2020          5.0        0.0
# 3      AFG      Asia  Afghanistan  27/02/2020          5.0        0.0
# 4      AFG      Asia  Afghanistan  28/02/2020          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
covid_file_clean = covid_file[['location','gdp_per_capita','life_expectancy','human_development_index']]
covid_file_clean.head()
# Out:
#       location  gdp_per_capita  life_expectancy  human_development_index
# 0  Afghanistan        1803.987            64.83                    0.511
# 1  Afghanistan        1803.987            64.83                    0.511
# 2  Afghanistan        1803.987            64.83                    0.511
# 3  Afghanistan        1803.987            64.83                    0.511
# 4  Afghanistan        1803.987            64.83                    0.511

# %%
covid_file_clean = covid_file_clean.rename(columns={'location':'country'
                                     })
covid_file_clean.head()
# Out:
#        country  gdp_per_capita  life_expectancy  human_development_index
# 0  Afghanistan        1803.987            64.83                    0.511
# 1  Afghanistan        1803.987            64.83                    0.511
# 2  Afghanistan        1803.987            64.83                    0.511
# 3  Afghanistan        1803.987            64.83                    0.511
# 4  Afghanistan        1803.987            64.83                    0.511

# %%
data_per_country = covid_file_clean.groupby(['country']).aggregate({'gdp_per_capita':np.max,
                                                                                      'life_expectancy':np.max,
                                                                                      'human_development_index':np.max,
                                                                                      })
data_per_country = data_per_country.reset_index()
data_per_country.head()
# Out:
#        country  gdp_per_capita  life_expectancy  human_development_index
# 0  Afghanistan        1803.987            64.83                    0.511
# 1       Africa             NaN              NaN                      NaN
# 2      Albania       11803.431            78.57                    0.795
# 3      Algeria       13913.839            76.88                    0.748
# 4      Andorra             NaN            83.73                    0.868

# %%
data_per_country_0 = data_per_country.fillna(0)
data_per_country_0.head()
# Out:
#        country  gdp_per_capita  life_expectancy  human_development_index
# 0  Afghanistan        1803.987            64.83                    0.511
# 1       Africa           0.000             0.00                    0.000
# 2      Albania       11803.431            78.57                    0.795
# 3      Algeria       13913.839            76.88                    0.748
# 4      Andorra           0.000            83.73                    0.868

# %%
final_dataset = pd.DataFrame(data_per_country_0)
final_dataset.head()
# Out:
#        country  gdp_per_capita  life_expectancy  human_development_index
# 0  Afghanistan        1803.987            64.83                    0.511
# 1       Africa           0.000             0.00                    0.000
# 2      Albania       11803.431            78.57                    0.795
# 3      Algeria       13913.839            76.88                    0.748
# 4      Andorra           0.000            83.73                    0.868

# %%
vax_file = './Resources/VaxbyMonth.csv'

# %%
vax_file = pd.read_csv(vax_file)

# %%
vax_file.head()
# Out:
#    Unnamed: 0      country  date  total_vaccinations  people_vaccinated  \
# 0           0  Afghanistan     2              8200.0             8200.0
# 1           1  Afghanistan     3             54000.0            54000.0
# 2           2  Afghanistan     4            240000.0           240000.0
# 3           3  Afghanistan     5            600152.0           480226.0
# 4           4  Afghanistan     6            886854.0           699200.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  \
# 0                      0.0                0.000000
# 1                      0.0                0.000000
# 2                      0.0                0.000000
# 3                 119926.0               92.225806
# 4                 187654.0              133.833333
#
#    average_daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 1171.714286                            0.02
# 1                 2770.774194                            0.14
# 2                 7320.200000                            0.60
# 3                 9220.580645                            1.51
# 4                 8096.633333                            2.23
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                           0.02                                 0.00
# 1                           0.14                                 0.00
# 2                           0.60                                 0.00
# 3                           1.21                                 0.30
# 4                           1.76                                 0.47
#
#    average_daily_vaccinations_per_million
# 0                               29.142857
# 1                               69.483871
# 2                              183.700000
# 3                              231.322581
# 4                              203.233333

# %%
total_vax_df = vax_file.groupby(['country']).agg(total_vaccinations=('total_vaccinations_per_hundred',max))
total_vax_df.head()
# Out:
#              total_vaccinations
# country
# Afghanistan               13.13
# Albania                   75.40
# Algeria                   27.55
# Andorra                  137.59
# Angola                    30.41

# %%
complete_data = pd.merge(final_dataset,total_vax_df,on='country')
complete_data.head()
# Out:
#        country  gdp_per_capita  life_expectancy  human_development_index  \
# 0  Afghanistan        1803.987            64.83                    0.511
# 1      Albania       11803.431            78.57                    0.795
# 2      Algeria       13913.839            76.88                    0.748
# 3      Andorra           0.000            83.73                    0.868
# 4       Angola        5819.495            61.15                    0.581
#
#    total_vaccinations
# 0               13.13
# 1               75.40
# 2               27.55
# 3              137.59
# 4               30.41

# %%
#correlation 
sns.heatmap(complete_data.corr(), linewidths=.5, annot=True, fmt=".2f")
plt.title('Correlations', fontsize=16)
plt.show()

# %%
plt.rcParams['figure.figsize'] = [6, 6]
x_values = complete_data["gdp_per_capita"]
y_values = complete_data["total_vaccinations"]
plt.scatter(x_values,y_values)
plt.title('GDP vs Total vaccinations', size=16)
plt.xlabel('GDP')
plt.ylabel('Total Vaccinations')
plt.show()

# %%
plt.rcParams['figure.figsize'] = [6, 5]
x_values = complete_data["gdp_per_capita"]
y_values = complete_data["total_vaccinations"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('GDP')
plt.ylabel('Total vaccinations')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.2514597885998458

# %%
plt.rcParams['figure.figsize'] = [6, 5]
x_values = complete_data["life_expectancy"]
y_values = complete_data["total_vaccinations"]
plt.scatter(x_values,y_values)
plt.title('Life expectancy vs Total vaccinations', size=16)
plt.xlabel('Life expectancy')
plt.ylabel('Total vaccinations')
plt.show()

# %%
plt.rcParams['figure.figsize'] = [6, 6]
x_values = complete_data["life_expectancy"]
y_values = complete_data["total_vaccinations"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Life Expectancy')
plt.ylabel('Total vaccinations')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.09339689748384691

# %%
plt.rcParams['figure.figsize'] = [6, 5]
x_values = complete_data["human_development_index"]
y_values = complete_data["total_vaccinations"]
plt.scatter(x_values,y_values)
plt.title('Human development index vs Total vaccinations', size=16)
plt.xlabel('Human development index')
plt.ylabel('Total vaccinations')
plt.show()

# %%
plt.rcParams['figure.figsize'] = [6, 6]
x_values = complete_data["human_development_index"]
y_values = complete_data["total_vaccinations"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('HDI')
plt.ylabel('Total vaccinations')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.009723572849191925

# %%
#15 countries with the highest vaccination rate
top_fifteen_vaccination = complete_data.nlargest(15,['total_vaccinations'])
top_fifteen_vaccination
# Out:
#                   country  gdp_per_capita  life_expectancy  \
# 76              Gibraltar           0.000            79.93
# 49                   Cuba           0.000            78.80
# 207  United Arab Emirates       67293.483            77.97
# 40                  Chile       22767.037            80.18
# 89                Iceland       46482.958            82.99
# 156              Pitcairn           0.000             0.00
# 210               Uruguay       20551.409            77.91
# 123                 Malta       36513.323            82.53
# 100                Jersey           0.000             0.00
# 37         Cayman Islands       49903.029            83.92
# 173            Seychelles       26382.287            73.40
# 41                  China       15308.712            76.91
# 158              Portugal       27936.896            82.05
# 208        United Kingdom       39753.244            81.32
# 54                Denmark       46682.515            80.90
#
#      human_development_index  total_vaccinations
# 76                     0.000              303.22
# 49                     0.783              255.29
# 207                    0.890              221.45
# 40                     0.851              219.34
# 89                     0.949              200.73
# 156                    0.000              200.00
# 210                    0.817              196.77
# 123                    0.895              191.46
# 100                    0.000              190.03
# 37                     0.000              189.05
# 173                    0.796              181.44
# 41                     0.761              179.47
# 158                    0.864              178.38
# 208                    0.932              176.71
# 54                     0.940              175.72

# %%
#15 countries with the highest GDP
top_fifteen_gdp = complete_data.nlargest(15,['gdp_per_capita'])
top_fifteen_gdp
# Out:
#                   country  gdp_per_capita  life_expectancy  \
# 159                 Qatar      116935.600            80.23
# 117                 Macao      104861.851            84.24
# 116            Luxembourg       94277.965            82.25
# 175             Singapore       85535.383            83.62
# 29                 Brunei       71809.251            75.86
# 94                Ireland       67335.293            82.30
# 207  United Arab Emirates       67293.483            77.97
# 106                Kuwait       65530.537            75.49
# 147                Norway       64800.057            82.40
# 189           Switzerland       57410.166            83.78
# 168            San Marino       56861.470            84.97
# 87              Hong Kong       56054.920            84.86
# 209         United States       54225.446            78.86
# 21                Bermuda       50669.315            82.59
# 37         Cayman Islands       49903.029            83.92
#
#      human_development_index  total_vaccinations
# 159                    0.848              172.48
# 117                    0.000              143.11
# 116                    0.916              147.65
# 175                    0.938              174.00
# 29                     0.838              174.84
# 94                     0.955              171.73
# 207                    0.890              221.45
# 106                    0.806              153.31
# 147                    0.957              165.94
# 189                    0.955              143.25
# 168                    0.000              143.11
# 87                     0.949              127.56
# 209                    0.926              145.39
# 21                     0.000              171.55
# 37                     0.000              189.05

# %%
#15 countries with lowest vaccine rate
bottom_fifteen_vaccination = complete_data.nsmallest(15,['total_vaccinations'])
bottom_fifteen_vaccination
# Out:
#                           country  gdp_per_capita  life_expectancy  \
# 32                        Burundi         702.225            61.58
# 53   Democratic Republic of Congo         808.133            60.68
# 85                          Haiti        1653.173            64.00
# 39                           Chad        1768.153            54.24
# 183                   South Sudan        1569.888            57.85
# 216                         Yemen        1479.147            66.12
# 118                    Madagascar        1416.440            67.04
# 193                      Tanzania        2683.304            65.46
# 31                   Burkina Faso        1703.102            61.58
# 34                       Cameroon        3364.926            59.29
# 142                         Niger         926.000            62.42
# 122                          Mali        2014.306            59.31
# 152              Papua New Guinea        3823.194            64.50
# 143                       Nigeria        5338.454            54.69
# 217                        Zambia        3689.251            63.89
#
#      human_development_index  total_vaccinations
# 32                     0.433                0.03
# 53                     0.480                0.24
# 85                     0.510                1.60
# 39                     0.398                1.63
# 183                    0.433                2.27
# 216                    0.470                2.58
# 118                    0.528                2.61
# 193                    0.529                2.76
# 31                     0.452                3.08
# 34                     0.563                3.56
# 142                    0.394                3.87
# 122                    0.434                4.62
# 152                    0.555                5.12
# 143                    0.539                5.30
# 217                    0.584                6.57

# %%
#15 countries with lowest GDP
bottom_fifteen_gdp = complete_data.nsmallest(15,['gdp_per_capita'])
bottom_fifteen_gdp
# Out:
#                              country  gdp_per_capita  life_expectancy  \
# 3                            Andorra             0.0            83.73
# 5                           Anguilla             0.0            81.88
# 24   Bonaire Sint Eustatius and Saba             0.0            77.79
# 28            British Virgin Islands             0.0            79.07
# 45                      Cook Islands             0.0            76.25
# 49                              Cuba             0.0            78.80
# 50                           Curacao             0.0            78.88
# 65                    Faeroe Islands             0.0            80.67
# 66                  Falkland Islands             0.0            81.44
# 70                  French Polynesia             0.0            77.66
# 76                         Gibraltar             0.0            79.93
# 78                         Greenland             0.0            71.70
# 81                          Guernsey             0.0             0.00
# 95                       Isle of Man             0.0            81.40
# 100                           Jersey             0.0             0.00
#
#      human_development_index  total_vaccinations
# 3                      0.868              137.59
# 5                      0.000              134.11
# 24                     0.000              135.55
# 28                     0.000              115.02
# 45                     0.000              138.44
# 49                     0.783              255.29
# 50                     0.000              120.99
# 65                     0.000              159.72
# 66                     0.000              124.91
# 70                     0.000              113.61
# 76                     0.000              303.22
# 78                     0.000              137.37
# 81                     0.000              164.80
# 95                     0.000              156.36
# 100                    0.000              190.03
